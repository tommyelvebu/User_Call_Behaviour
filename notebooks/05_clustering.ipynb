# %% [markdown]
# ## 05 - Clustering Unknown Contacts
# *Unsupervised exploration to find hidden patterns in the murky waters*

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
project_root = Path.cwd().parent
df_all = pd.read_csv(project_root / 'data' / 'features' / 'contact_features.csv')
df = df_all[df_all['category'] == 'Unknown'].copy()

# %%
clustering_features = [
    'pct_business_hours',
    'pct_late_night',
    'avg_hour',
    'avg_duration',
    'max_duration',
    'calls_per_month',
    'days_active',
]

# %% [markdown]
# ### Feature Selection
# *Picking the behavioral fingerprint*
#
# We skip total_duration and total_calls - these are captured by calls_per_month and avg_duration. Redundant features skew clustering distance calculations

# %%
X = df[clustering_features].copy()
X.head()
# Out:
#    pct_business_hours  pct_late_night   avg_hour  avg_duration  max_duration  \
# 1            1.000000        0.000000  10.000000           4.0             4
# 2            1.000000        0.000000  10.000000          39.0            73
# 3            1.000000        0.000000   9.000000          18.0            18
# 4            0.615385        0.015385  14.223077          18.0           462
# 5            0.909091        0.000000  11.181818           8.0            62
#
#    calls_per_month  days_active
# 1         1.000000            0
# 2         2.000000            0
# 3         1.000000            0
# 4        58.208955           37
# 5         0.563140          556

# %% [markdown]
# ### Scale Features
# *Standardization so duration doesn't dominate*

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### Finding Optimal K
# *How many clusters should we use?*
#
# - **Elbow method** measures cluster tightness - look for where adding clusters stops helping
# - **Silhouette score** measures separation - higher is better

# %%
inertias = []
silhouettes = []
K_range = range(2, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertias.append(kmeans.inertia_)
    silhouettes.append(silhouette_score(X_scaled, kmeans.labels_))

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(K_range, inertias, 'bo-', linewidth=2, markersize=8)
axes[0].set_xlabel('Number of Clusters (K)')
axes[0].set_ylabel('Inertia')
axes[0].set_title('Elbow Method')

axes[1].plot(K_range, silhouettes, 'go-', linewidth=2, markersize=8)
axes[1].set_xlabel('Number of Clusters (K)')
axes[1].set_ylabel('Silhouette Score')
axes[1].set_title('Silhouette Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# Elbow bends around K=5, silhouette peaks around K=7. We go with K=5 - we have 4 known categories, so a 5th might expose a hidden group
#
# ### K-Means Clustering
# *Letting the algorithm find 5 groups*

# %%
kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X_scaled)

df['cluster'].value_counts().sort_index()
# Out:
# /Users/tommyandreelvebu/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/tommyandreelvebu/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/tommyandreelvebu/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/tommyandreelvebu/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/tommyandreelvebu/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/tommyandreelvebu/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# cluster
# 0    1218
# 1     501
# 2      16
# 3     217
# 4      25
# Name: count, dtype: int64

# %% [markdown]
# ### Where Did the Muffens Land?
# *Tracking our suspicious five*

# %%
muffens = ['Duma', 'Eric', 'Alli', 'Park', 'Zohra']
df[df['name'].isin(muffens)][['name', 'cluster'] + clustering_features]
# Out:
#        name  cluster  pct_business_hours  pct_late_night   avg_hour  \
# 32     Alli        4            0.659669        0.000000  12.898343
# 320    Duma        4            0.304762        0.128571  14.038095
# 389    Eric        3            0.310502        0.041096  14.305936
# 1246   Park        3            0.728223        0.000000  13.393728
# 2062  Zohra        3            0.689655        0.000000  12.098522
#
#       avg_duration  max_duration  calls_per_month  days_active
# 32            22.0          2068        26.384840          999
# 320           24.5          1769        19.626168          291
# 389           27.0          1722         6.865204          927
# 1246           5.0           372        13.909532          589
# 2062          40.0           818        11.825243          485

# %% [markdown]
# Duma and Alli landed in Cluster 4, while Eric, Park, and Zohra are in Cluster 3. Interesting - Duma and Eric split
#
# ### Cluster Profiles
# *What does each group look like?*

# %%
df.groupby('cluster')[clustering_features].mean().round(2)
# Out:
#          pct_business_hours  pct_late_night  avg_hour  avg_duration  \
# cluster
# 0                      0.96            0.00     12.34         64.20
# 1                      0.07            0.00     14.50         55.83
# 2                      0.11            0.77     19.28         81.19
# 3                      0.65            0.01     13.08         46.67
# 4                      0.46            0.08     13.90       1059.30
#
#          max_duration  calls_per_month  days_active
# cluster
# 0              103.71             1.70        20.39
# 1              102.89             1.64        19.64
# 2              104.00             1.43        43.00
# 3              314.54             1.18       554.11
# 4             3546.16             8.73       285.52

# %% [markdown]
# Duma and Alli grouped in Cluster 4 because of long calls, not late-night activity. Eric, Park, and Zohra in Cluster 3 because of long-term relationships
#
# Plot twist - our suspects are not in the *real suspicious cluster*. Cluster 2 has 77% late-night calls with only 16 people
#
# ### Cluster 2: The Night Owls
# *16 contacts with 77% late-night calls - who are they?*

# %%
df[df['cluster'] == 2][['name', 'predicted_category', 'cluster'] + clustering_features].sort_values('pct_late_night', ascending=False)
# Out:
#          name  predicted_category  cluster  pct_business_hours  \
# 96     Basson  Important Contacts        2                 0.0
# 521     Ganas  Important Contacts        2                 0.0
# 528     Gavin  Important Contacts        2                 0.0
# 557   Goodman  Important Contacts        2                 0.0
# 989     Loots    Service Provider        2                 0.0
# 1373    Quill  Important Contacts        2                 0.0
# 2058    Zitha    Service Provider        2                 0.0
# 2061   Zoghby            Supplier        2                 0.0
# 671     Human  Important Contacts        2                 0.0
# 1600   Themba  Important Contacts        2                 0.2
# 448    Fester    Service Provider        2                 0.0
# 654    Holder  Important Contacts        2                 0.0
# 853     Kelly    Service Provider        2                 0.5
# 969     Lesch    Service Provider        2                 0.0
# 995     Louis    Service Provider        2                 0.5
# 1270    Peter  Important Contacts        2                 0.5
#
#       pct_late_night   avg_hour  avg_duration  max_duration  calls_per_month  \
# 96          1.000000  23.000000          10.0            10         1.000000
# 521         1.000000  21.000000           2.0             2         1.000000
# 528         1.000000  21.000000          39.5            77         2.000000
# 557         1.000000  21.500000          38.0            42         2.000000
# 989         1.000000  21.000000         172.0           172         1.000000
# 1373        1.000000  21.000000          34.0            34         1.000000
# 2058        1.000000  22.000000         158.0           158         1.000000
# 2061        1.000000  21.000000          17.0            17         1.000000
# 671         0.666667  16.666667           4.0             5         2.368421
# 1600        0.600000  12.800000           4.0            39         2.777778
# 448         0.500000  19.500000         122.5           154         0.341880
# 654         0.500000  20.500000          31.0            42         1.935484
# 853         0.500000  15.000000         307.5           440         0.172414
# 969         0.500000  20.000000         153.5           156         1.875000
# 995         0.500000  15.000000         161.0           248         1.935484
# 1270        0.500000  17.500000          45.0            68         1.395349
#
#       days_active
# 96              0
# 521             0
# 528             0
# 557             0
# 989             0
# 1373            0
# 2058            0
# 2061            0
# 671             8
# 1600           24
# 448           321
# 654             1
# 853           318
# 969             2
# 995             1
# 1270           13

# %% [markdown]
# Fake-muffens. They look suspicious (100% late-night) but calls are short (20-40s) and infrequent. Pattern is quick late-night check-ins, not intimate conversations
#
# ### Cluster 4: The Heavy Talkers
# *25 contacts with 17-min average calls - Duma's crew*

# %%
df[df['cluster'] == 4][['name', 'predicted_category', 'cluster'] + clustering_features].sort_values('pct_late_night', ascending=False)
# Out:
#          name predicted_category  cluster  pct_business_hours  pct_late_night  \
# 1471    Rowan   Service Provider        4            0.000000        0.500000
# 1097    Ncube   Service Provider        4            0.333333        0.333333
# 1785   Vosser             Family        4            0.309524        0.222222
# 1958   Yeates             Family        4            0.256757        0.202703
# 392   Erskine             Family        4            0.375000        0.175000
# 1058   Modiba   Service Provider        4            0.296296        0.148148
# 320      Duma             Family        4            0.304762        0.128571
# 1617     Tiro             Family        4            0.252525        0.060606
# 99       Beer   Service Provider        4            0.431034        0.051724
# 286      Devi             Family        4            0.425287        0.034483
# 425     Faith             Family        4            0.538462        0.028846
# 4       Abdol             Family        4            0.615385        0.015385
# 659      Hope             Family        4            0.688889        0.011111
# 707    Ingham   Service Provider        4            1.000000        0.000000
# 721     Irish   Service Provider        4            1.000000        0.000000
# 32       Alli           Supplier        4            0.659669        0.000000
# 601      Hans   Service Provider        4            1.000000        0.000000
# 1213   Orgill   Service Provider        4            0.000000        0.000000
# 1409     Rall   Service Provider        4            1.000000        0.000000
# 586     Gumbi   Service Provider        4            0.000000        0.000000
# 460   Fischer   Service Provider        4            1.000000        0.000000
# 1760   Vernon   Service Provider        4            0.000000        0.000000
# 454     Finca   Service Provider        4            0.500000        0.000000
# 226      Cook             Family        4            0.589286        0.000000
# 2019     Zako   Service Provider        4            0.000000        0.000000
#
#        avg_hour  avg_duration  max_duration  calls_per_month  days_active
# 1471  20.000000        3601.5          7200         2.000000            0
# 1097  15.111111         461.0          2832         0.551020          460
# 1785  13.555556           5.0          2566        12.038217          284
# 1958  14.297297          67.5          3242        15.205479          116
# 392   14.575000          52.0          7200        12.121212           69
# 1058  14.407407         390.0          5850         2.334294          317
# 320   14.038095          24.5          1769        19.626168          291
# 1617  14.737374          73.0          4148         8.658892          313
# 99    13.465517         308.0          6394         1.879050          896
# 286   15.229885          16.0          3739         2.785486          907
# 425   12.836538          40.5          2132        41.052632           46
# 4     14.223077          18.0           462        58.208955           37
# 659   13.011111          82.5          7141         2.912621          897
# 707   12.000000        1927.0          1927         1.000000            0
# 721   10.000000        2114.5          4225         1.935484            1
# 32    12.898343          22.0          2068        26.384840          999
# 601   16.000000        1606.0          1606         1.000000            0
# 1213  19.000000        4016.0          4016         1.000000            0
# 1409  13.000000        1377.0          1377         1.000000            0
# 586    7.000000        4801.0          4801         1.000000            0
# 460   11.000000        1128.0          1438         2.000000            0
# 1760  20.000000        1375.0          1375         1.000000            0
# 454   10.500000        1516.0          2920         0.106195          535
# 226   14.732143           5.0          5561         1.832061          887
# 2019  12.000000        1455.5          2665         0.530973           83

# %% [markdown]
# Eish! Muffen-goldmine. New suspects: Rowan, Ncube, Modiba. All predicted as Service Provider by the tree, but no service provider talks for an hour at 8 PM
#
# ### New Suspects
# *Rowan, Ncube, Modiba - let's investigate*

# %%
calls = pd.read_csv(project_root / 'data' / 'processed' / 'calls_cleaned.csv')

new_suspects = ['Rowan', 'Ncube', 'Modiba']

summary = []
for name in new_suspects:
    person = calls[calls['name'] == name]
    late_night = len(person[(person['hour'] >= 21) | (person['hour'] < 6)])
    summary.append({
        'name': name,
        'total_calls': len(person),
        'period': f"{person['date_stamp'].min()} to {person['date_stamp'].max()}",
        'late_night_calls': late_night,
        'max_call_min': round(person['duration_in_seconds'].max() / 60, 1),
        'peak_hour': person['hour'].mode().iloc[0]
    })

pd.DataFrame(summary)
# Out:
#      name  total_calls                    period  late_night_calls  \
# 0   Rowan            2  2022-11-22 to 2022-11-22                 1
# 1   Ncube            9  2022-09-19 to 2023-12-23                 3
# 2  Modiba           27  2023-08-31 to 2024-07-13                 4
#
#    max_call_min  peak_hour
# 0         120.0         19
# 1          47.2         21
# 2          97.5          8

# %% [markdown]
# **Verdict:**
# - **Rowan:** False alarm - only 2 calls on same day, likely one-off support call
# - **Ncube:** Minor interest - 9 calls over 15 months, low frequency but 47-min max
# - **Modiba:** New muffen - 27 calls over 11 months, 97-min max, still ongoing, peak hour 8 PM

# %% [markdown]
# ---
#
# ## Summary
#
# K-Means clustering (K=5) on 1,977 Unknown contacts using 7 behavioral features
#
# | Cluster | Size | Profile |
# |---------|------|---------|
# | 0 | 1,218 | Business contacts (96% business hours) |
# | 1 | 501 | Evening callers (7% business hours) |
# | 2 | 16 | Night owls (77% late-night, short calls) |
# | 3 | 217 | Long-term regulars (554 days active) |
# | 4 | 25 | Heavy talkers (17-min avg, 59-min max) |
#
# **Muffens verdict:**
# - Duma → Cluster 4 (long calls)
# - Eric → Cluster 3 (long-term relationship)
# - Modiba → Cluster 4 (new suspect: 97-min calls, ongoing)
#
# **Key finding:** Cluster 4 is the muffen cluster. Only 25 contacts with unusually long calls. The supervised model labeled Modiba as "Service Provider" but no service provider talks for 97 minutes at 8 PM. Clustering caught what the tree missed
