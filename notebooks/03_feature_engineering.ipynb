# %% [markdown]
# ## 03 - Feature Engineering
#
# *Transform call-level data into contact-level features for modeling*

# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
project_root = Path.cwd().parent

df = pd.read_csv(
    project_root / 'data' / 'processed' / 'calls_cleaned.csv',
    parse_dates=['date_stamp']
)

# %% [markdown]
# ### Add Late Night Flag
#
# Calls between 21:00 and 06:00 - the *muffens* hours

# %%
df['is_late_night'] = (df['hour'] >= 21) | (df['hour'] < 6)

# %% [markdown]
# ### Build Contact-Level Features

# %%
contact_features = df.groupby('name').agg(
    category=('category', 'first'),
    total_calls=('name', 'count'),
    total_duration=('duration_in_seconds', 'sum'),
    avg_duration=('duration_in_seconds', 'median'),
    max_duration=('duration_in_seconds', 'max'),
    pct_business_hours=('is_business_hours', 'mean'),
    pct_late_night=('is_late_night', 'mean'),
    avg_hour=('hour', 'mean'),
    first_call=('date_stamp', 'min'),
    last_call=('date_stamp', 'max')
).reset_index()

# %%
contact_features['days_active'] = (contact_features['last_call'] - contact_features['first_call']).dt.days
contact_features['is_one_off'] = contact_features['total_calls'] == 1
contact_features['calls_per_month'] = contact_features['total_calls'] / (contact_features['days_active'] / 30 + 1)
contact_features['is_active'] = contact_features['last_call'] >= '2024-06-01'

# %% [markdown]
# ### Preview

# %%
contact_features.head(10)
# Out:
#            name  category  total_calls  total_duration  avg_duration  \
# 0  ASBIS Africa  Supplier            9             834          96.0
# 1         Aaron   Unknown            1               4           4.0
# 2         Abbas   Unknown            2              78          39.0
# 3        Abbott   Unknown            1              18          18.0
# 4         Abdol   Unknown          130            8097          18.0
# 5        Abdool   Unknown           11             218           8.0
# 6         Abdul   Unknown           26             486           9.5
# 7       Abdulla   Unknown            3              90          36.0
# 8          Abel   Unknown           96            9438          41.5
# 9       Abraham   Unknown            1              11          11.0
#
#    max_duration  pct_business_hours  pct_late_night   avg_hour first_call  \
# 0           244            1.000000        0.000000   9.888889 2024-01-26
# 1             4            1.000000        0.000000  10.000000 2022-05-27
# 2            73            1.000000        0.000000  10.000000 2022-05-27
# 3            18            1.000000        0.000000   9.000000 2023-03-22
# 4           462            0.615385        0.015385  14.223077 2022-05-27
# 5            62            0.909091        0.000000  11.181818 2023-03-22
# 6           170            0.192308        0.038462  17.038462 2022-05-27
# 7            48            0.000000        0.000000  17.333333 2024-02-14
# 8           925            0.041667        0.020833  18.458333 2022-01-01
# 9            11            1.000000        0.000000  11.000000 2024-02-15
#
#    last_call  days_active  is_one_off  calls_per_month  is_active
# 0 2024-02-22           27       False         4.736842      False
# 1 2022-05-27            0        True         1.000000      False
# 2 2022-05-27            0       False         2.000000      False
# 3 2023-03-22            0        True         1.000000      False
# 4 2022-07-03           37       False        58.208955      False
# 5 2024-09-28          556       False         0.563140       True
# 6 2023-07-17          416       False         1.748879      False
# 7 2024-05-04           80       False         0.818182      False
# 8 2024-06-08          889       False         3.133841       True
# 9 2024-02-15            0        True         1.000000      False

# %%
contact_features.describe()
# Out:
#        total_calls  total_duration  avg_duration  max_duration  \
# count  2091.000000     2091.000000   2091.000000   2091.000000
# mean     11.933046     1230.779531     82.023195    217.619799
# min       1.000000        1.000000      1.000000      1.000000
# 25%       1.000000       33.000000     13.000000     28.000000
# 50%       2.000000       91.000000     38.500000     68.000000
# 75%       4.000000      272.000000     78.250000    156.000000
# max    2413.000000   222060.000000   4801.000000   7200.000000
# std      83.240973     9477.446439    216.531427    604.875805
#
#        pct_business_hours  pct_late_night     avg_hour  \
# count         2091.000000     2091.000000  2091.000000
# mean             0.696408        0.009625    13.025790
# min              0.000000        0.000000     6.000000
# 25%              0.369318        0.000000    11.000000
# 50%              1.000000        0.000000    13.000000
# 75%              1.000000        0.000000    15.000000
# max              1.000000        1.000000    23.000000
# std              0.406772        0.075022     2.685936
#
#                           first_call                      last_call  \
# count                           2091                           2091
# mean   2023-03-15 02:50:06.025825024  2023-06-24 14:48:22.725968384
# min              2022-01-01 00:00:00            2022-01-03 00:00:00
# 25%              2022-06-13 00:00:00            2022-09-26 00:00:00
# 50%              2023-03-11 00:00:00            2023-07-17 00:00:00
# 75%              2023-12-08 00:00:00            2024-03-18 00:00:00
# max              2024-10-04 00:00:00            2024-10-04 00:00:00
# std                              NaN                            NaN
#
#        days_active  calls_per_month
# count  2091.000000      2091.000000
# mean    101.498804         1.896536
# min       0.000000         0.076923
# 25%       0.000000         1.000000
# 50%       0.000000         1.000000
# 75%      36.000000         2.000000
# max    1006.000000        74.018405
# std     223.114163         3.491529

# %% [markdown]
# ### Feature Distributions by Category

# %%
contact_features.groupby('category').agg(
    num_contacts=('name', 'count'),
    avg_calls=('total_calls', 'mean'),
    avg_duration=('avg_duration', 'mean'),
    avg_pct_business=('pct_business_hours', 'mean'),
    avg_pct_late_night=('pct_late_night', 'mean'),
    pct_one_off=('is_one_off', 'mean')
).round(3)
# Out:
#                     num_contacts  avg_calls  avg_duration  avg_pct_business  \
# category
# Family                        17    578.059        40.500             0.508
# Important Contacts             6     97.333        40.500             0.504
# Service Provider              51      5.941       442.912             0.844
# Supplier                      40     66.475        97.950             0.924
# Unknown                     1977      5.857        72.874             0.690
#
#                     avg_pct_late_night  pct_one_off
# category
# Family                           0.032        0.000
# Important Contacts               0.052        0.167
# Service Provider                 0.009        0.353
# Supplier                         0.000        0.175
# Unknown                          0.009        0.464

# %% [markdown]
# ### Our Muffens
#
# How do Duma and Eric look in the feature space?

# %%
muffens = ['Duma', 'Eric', 'Alli', 'Park', 'Zohra']
contact_features[contact_features['name'].isin(muffens)]
# Out:
#        name category  total_calls  total_duration  avg_duration  max_duration  \
# 32     Alli  Unknown          905           44383          22.0          2068
# 320    Duma  Unknown          210           14915          24.5          1769
# 389    Eric  Unknown          219           21099          27.0          1722
# 1246   Park  Unknown          287            6937           5.0           372
# 2062  Zohra  Unknown          203           16865          40.0           818
#
#       pct_business_hours  pct_late_night   avg_hour first_call  last_call  \
# 32              0.659669        0.000000  12.898343 2022-01-03 2024-09-28
# 320             0.304762        0.128571  14.038095 2022-01-16 2022-11-03
# 389             0.310502        0.041096  14.305936 2022-01-17 2024-08-01
# 1246            0.728223        0.000000  13.393728 2022-02-28 2023-10-10
# 2062            0.689655        0.000000  12.098522 2023-03-12 2024-07-09
#
#       days_active  is_one_off  calls_per_month  is_active
# 32            999       False        26.384840       True
# 320           291       False        19.626168      False
# 389           927       False         6.865204       True
# 1246          589       False        13.909532      False
# 2062          485       False        11.825243       True

# %% [markdown]
# ### Save Features

# %%
contact_features.to_csv(project_root / 'data' / 'features' / 'contact_features.csv', index=False)

# %% [markdown]
# ---
#
# ## Summary
#
# Created 14 features for 2,091 contacts:
#
# | Feature | Description |
# |---------|-------------|
# | `category` | Original label (target for supervised learning) |
# | `total_calls` | Number of calls to this contact |
# | `total_duration` | Total seconds spent on calls |
# | `avg_duration` | Median call length |
# | `max_duration` | Longest call |
# | `pct_business_hours` | % calls during 8-17 Mon-Fri |
# | `pct_late_night` | % calls between 21:00-06:00 |
# | `avg_hour` | Average hour of day |
# | `first_call` | Relationship start date |
# | `last_call` | Most recent call |
# | `days_active` | Span of relationship in days |
# | `is_one_off` | True if only called once |
# | `calls_per_month` | Average monthly frequency |
# | `is_active` | True if called recently (2024) |
